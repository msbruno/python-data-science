# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime,date
# %matplotlib inline

# %%
df_origin = pd.read_excel(r'/home/silva/desenvolvedor/data_science/python/fundamentos/balanco.xls', sheet_name='Dem. Result.')
# Out:
# WARNING *** file size (69996) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df_origin
# Out:
#    XLSWrite 1.34 Copyright(c) 1999,2000 Axolot Data  \
# 0
# 1             Receita Bruta de Vendas e/ou Serviços
# 2                         Deduções da Receita Bruta
# 3           Receita Líquida de Vendas e/ou Serviços
# 4              Custo de Bens e/ou Serviços Vendidos
# 5                                   Resultado Bruto
# 6                               Despesas Com Vendas
# 7                 Despesas Gerais e Administrativas
# 8       Perdas pela Não Recuperabilidade de Ativos
# 9                      Outras Receitas Operacionais
# 10                     Outras Despesas Operacionais
# 11            Resultado da Equivalência Patrimonial
# 12                                      Financeiras
# 13                             Receitas Financeiras
# 14                             Despesas Financeiras
# 15                        Resultado Não Operacional
# 16                                         Receitas
# 17                                         Despesas
# ...

# %%
df_origin.dtypes
# Out:
# XLSWrite 1.34 Copyright(c) 1999,2000 Axolot Data             object
# Demonstrativo de Resultado - ITAÚSA - Trimestres Isolados    object
# Unnamed: 2                                                   object
# Unnamed: 3                                                   object
# Unnamed: 4                                                   object
# Unnamed: 5                                                   object
# Unnamed: 6                                                   object
# Unnamed: 7                                                   object
# Unnamed: 8                                                   object
# Unnamed: 9                                                   object
# Unnamed: 10                                                  object
# Unnamed: 11                                                  object
# Unnamed: 12                                                  object
# Unnamed: 13                                                  object
# ...

# %%
df = df_origin.transpose()
df.head()
# Out:
#                                                             0   \
# XLSWrite 1.34 Copyright(c) 1999,2000 Axolot Data
# Demonstrativo de Resultado - ITAÚSA - Trimestre...  30/09/2018
# Unnamed: 2                                          30/06/2018
# Unnamed: 3                                          31/03/2018
# Unnamed: 4                                          31/12/2017
#
#                                                                                        1   \
# XLSWrite 1.34 Copyright(c) 1999,2000 Axolot Data    Receita Bruta de Vendas e/ou Serviços
# Demonstrativo de Resultado - ITAÚSA - Trimestre...                                      0
# Unnamed: 2                                                                              0
# Unnamed: 3                                                                              0
# Unnamed: 4                                                                              0
#
# ...

# %%
df = df.reset_index()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=43, step=1)

# %%
formatter_string = "%dd/%mm/%Y"

# %%
datetime.strptime('30/09/2018',formatter_string)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-19dc2b5f78c3> in <module>
# ----> 1 datetime.strptime('30/09/2018',formatter_string)
#
# /usr/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# /usr/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ...

# %%
df = df.set_index(df[df.columns[0]])

# %%
df = df.ix[:,]
# Out:
# /home/silva/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
 df.pivot(index='date', columns='variable', values='value')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-5bfa87b0490a> in <module>
# ...

# %%
x = df.iloc[23]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-7ccebea48119> in <module>
# ----> 1 x.index = 0
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in _set_axis(self, axis, labels, fastpath)
#     367
#     368         if not fastpath:
# --> 369             labels = _ensure_index(labels)
#     370
#     371         is_all_dates = labels.is_all_dates
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in _ensure_index(index_like, copy)
# ...
