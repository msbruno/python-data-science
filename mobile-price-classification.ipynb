# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r'/home/silva/Downloads/mobile-price.csv')
#https://github.com/msbruno/python-datas-cience/blob/master/datasets/mobile-price.csv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
# battery_power    2000 non-null int64
# blue             2000 non-null int64
# clock_speed      2000 non-null float64
# dual_sim         2000 non-null int64
# fc               2000 non-null int64
# four_g           2000 non-null int64
# int_memory       2000 non-null int64
# m_dep            2000 non-null float64
# mobile_wt        2000 non-null int64
# n_cores          2000 non-null int64
# pc               2000 non-null int64
# px_height        2000 non-null int64
# px_width         2000 non-null int64
# ram              2000 non-null int64
# sc_h             2000 non-null int64
# sc_w             2000 non-null int64
# talk_time        2000 non-null int64
# three_g          2000 non-null int64
# touch_screen     2000 non-null int64
# wifi             2000 non-null int64
# price_range      2000 non-null int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
df.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  sc_w  \
# 0        188        2     ...              20       756  2549     9     7
# 1        136        3     ...             905      1988  2631    17     3
# 2        145        5     ...            1263      1716  2603    11     2
# 3        131        6     ...            1216      1786  2769    16     8
# 4        141        2     ...            1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# 0         19        0             0     1            1
# 1          7        1             1     0            2
# 2          9        1             1     0            2
# 3         11        1             0     0            2
# 4         15        1             1     0            1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Verificando a existência de dados faltantes

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ## Explorando os dados e conhencendo o Dataset

# %% [markdown]
# ### Verificando algumas variáveis

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# min       0.000000     2.000000     0.100000    80.000000     1.000000
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000
# max       1.000000    64.000000     1.000000   200.000000     8.000000
#
#           ...         px_height     px_width          ram         sc_h  \
# count     ...       2000.000000  2000.000000  2000.000000  2000.000000
# mean      ...        645.108000  1251.515500  2124.213000    12.306500
# std       ...        443.780811   432.199447  1084.732044     4.213245
# min       ...          0.000000   500.000000   256.000000     5.000000
# 25%       ...        282.750000   874.750000  1207.500000     9.000000
# 50%       ...        564.000000  1247.000000  2146.500000    12.000000
# 75%       ...        947.250000  1633.000000  3064.500000    16.000000
# max       ...       1960.000000  1998.000000  3998.000000    19.000000
#
#               sc_w    talk_time      three_g  touch_screen         wifi  \
# count  2000.000000  2000.000000  2000.000000   2000.000000  2000.000000
# mean      5.767000    11.011000     0.761500      0.503000     0.507000
# std       4.356398     5.463955     0.426273      0.500116     0.500076
# min       0.000000     2.000000     0.000000      0.000000     0.000000
# 25%       2.000000     6.000000     1.000000      0.000000     0.000000
# 50%       5.000000    11.000000     1.000000      1.000000     1.000000
# 75%       9.000000    16.000000     1.000000      1.000000     1.000000
# max      18.000000    20.000000     1.000000      1.000000     1.000000
#
#        price_range
# count  2000.000000
# mean      1.500000
# std       1.118314
# min       0.000000
# 25%       0.750000
# 50%       1.500000
# 75%       2.250000
# max       3.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ### Verificando balanceameno

# %%
classes = pd.value_counts(df['price_range'], sort = True).sort_index()
classes.plot(kind = 'bar')
plt.title("Faixa de precos")
plt.xlabel("Faixa")
plt.ylabel("Frequencia")
# Out:
# Text(0,0.5,'Frequencia')

# %% [markdown]
# ### Verificando correlações

# %%
sns.boxplot(x="price_range", y="battery_power", data=df)

# %%
sns.boxplot(x="price_range", y="ram", data=df)

# %%
sns.boxplot(x="price_range", y="px_width", data=df)

# %% [markdown]
# ### Criando matriz de correlação e gráfico de correlação

# %%
#Verificando as correlações
corr = df.corr()

#plotando a matriz de correlação com seaborn
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

#Setando a figura matplotlib
f, ax = plt.subplots(figsize=(10, 9))

#Gerando paleta de divergencia
cmap = sns.diverging_palette(220, 10, as_cmap=True)

#Printando o mapa de calor com paleta de divergencia
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Criando modelos de classificação

# %%
entrada = df.drop('price_range',axis=1)
saida = df['price_range']
from sklearn.model_selection import train_test_split
entrada_treino, entrada_teste, saida_treino, saida_teste = train_test_split(entrada, saida, test_size=0.35, random_state=101)

# %% [markdown]
# ### Regressão logística com todas variáveis

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
lr = lr.fit(entrada_treino, saida_treino)
lr.score(entrada_teste, saida_teste)
# Out:
# 0.6228571428571429

# %% [markdown]
# ### Regressão logística com seleção de variáveis com alta correlação com a variável dependente

# %%
df_filtrado = df[['battery_power', 'ram', 'px_width', 'price_range']].copy()
entrada_filtrada = df_filtrado.drop(axis=1,columns='price_range')
entrada_treino_filtrado, entrada_teste_filtrado, saida_treino_filtrado, saida_teste_filtrado = train_test_split(entrada_filtrada, saida, test_size=0.35, random_state=101)

# %%
lr = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
lr = lr.fit(entrada_treino_filtrado, saida_treino_filtrado)
lr.score(entrada_teste_filtrado, saida_teste_filtrado)
# Out:
# 0.9

# %% [markdown]
# ### Árvore de decisão

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
dtc = DecisionTreeClassifier(random_state=0, criterion='entropy', max_depth=4)
#cross_val_score(dtc, entrada_treino_filtrado, saida_treino_filtrado, cv=10)

# %%
dtc = dtc.fit(entrada_treino_filtrado, saida_treino_filtrado)
dtc.score(entrada_teste_filtrado, saida_teste_filtrado)
# Out:
# 0.8

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn import tree
import pydotplus
import graphviz

# %%
dot_data = StringIO()
tree.export_graphviz(dtc, 
                out_file=dot_data,  
                feature_names=['battery_power', 'ram', 'px_width'],
                class_names= 'price_range',
                filled=True, 
                rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
def visualize_classifier(model, X, y, ax=None, cmap='rainbow'):
    ax = ax or plt.gca()
    
    # Plot the training points
    ax.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=cmap,
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # fit the estimator
    model.fit(X, y)
    xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                         np.linspace(*ylim, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

    # Create a color plot with the results
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap=cmap, clim=(y.min(), y.max()),
                           zorder=1)

    ax.set(xlim=xlim, ylim=ylim)

# %%
visualize_classifier(dtc, entrada_teste_filtrado, saida_teste_filtrado)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-2cdcac0827a9> in <module>()
# ----> 1 visualize_classifier(dtc, entrada_teste_filtrado, saida_teste_filtrado)
#
# <ipython-input-162-2012e9cc4787> in visualize_classifier(model, X, y, ax, cmap)
#       3
#       4     # Plot the training points
# ----> 5     ax.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=cmap,
#       6                clim=(y.min(), y.max()), zorder=3)
#       7     ax.axis('tight')
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    2485         """Return the cached item, item represents a label indexer."""
#    2486         cache = self._item_cache
# -> 2487         res = cache.get(item)
#    2488         if res is None:
#    2489             values = self._data.get(item)
#
# TypeError: unhashable type

# %%
# Parameters
n_classes = 4
plot_colors = "ryb"
plot_step = 0.02

import numpy as np, pandas as pd; plt.close("all")
index = pd.date_range("1 1 2000", periods=100,freq="m", name="date")
data = np.random.randn(100, 4).cumsum(axis=0)
wide_df = pd.DataFrame(data, index, ["a", "b", "c", "d"])
ax = sns.scatterplot(data=wide_df)
